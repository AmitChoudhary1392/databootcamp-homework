# %%
import pandas as pd
import numpy as np

# %%
books_df= pd.read_csv('../books1.csv').drop('Unnamed: 10', axis=1)

# %%
books_df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3       4  Harry Potter and the Chamber of Secrets (Harry...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors average_rating        isbn         isbn13  \
# 0  J.K. Rowling-Mary GrandPré           4.56   439785960  9780439785969
# 1  J.K. Rowling-Mary GrandPré           4.49   439358078  9780439358071
# 2  J.K. Rowling-Mary GrandPré           4.47   439554934  9780439554930
# 3                J.K. Rowling           4.41   439554896  9780439554893
# 4  J.K. Rowling-Mary GrandPré           4.55  043965548X  9780439655484
#
#   language_code # num_pages  ratings_count  text_reviews_count
# 0           eng         652        1944099               26249
# ...

# %% [markdown]
# recommending based on counts

# %%
ratings_count=pd.DataFrame(books_df.groupby('authors')['average_rating'].count())

# %%
ratings_count.sort_values('average_rating', ascending=False).head()
# Out:
#                   average_rating
# authors
# Agatha Christie               69
# Stephen King                  66
# Orson Scott Card              48
# Rumiko Takahashi              46
# P.G. Wodehouse                42

# %% [markdown]
# ### item based recommender system

# %% [markdown]
# Logistic regression as classifier

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from sklearn.linear_model import LogsiticRegression
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-1fb625923d21> in <module>
#       2 import numpy as np
#       3 from pandas import Series, DataFrame
# ----> 4 from sklearn.linear_model import LogsiticRegression
#
# ImportError: cannot import name 'LogsiticRegression' from 'sklearn.linear_model' (C:\Users\ruchi\Anaconda3\lib\site-packages\sklearn\linear_model\__init__.py)

# %%
books_df= pd.read_csv("books_df_280.csv")
books_df.head()
# Out:
#                      authors category/genre  \
# 0  ['Thomas G. Johnson Sr.']    ['Fiction']
# 1           ['Stephen King']    ['Fiction']
# 2         ['Franck Bouysse']    ['Fiction']
# 3          ['Jack Campbell']    ['Fiction']
# 4          ['Jill McCorkle']    ['Fiction']
#
#                                          description       id_book  \
# 0  The Trials of Worly the Ward is a historic fic...  rJqgupUXGUYC
# 1  Returns to the rich landscape of Mid-World in ...  Nvkwjw2LToEC
# 2  Sélection Prix Polar SNCF Les Doges, un lieu-d...  YYemCwAAQBAJ
# 3  Captain John “Black Jack” Geary tries a desper...  zs4VXctuga4C
# 4  Jo Spencer's conventional life is disrupted wh...  ouTaAnG0ipwC
#
#                                            image_url           isbn language  \
# 0  http://books.google.com/books/content?id=rJqgu...  9781456736866       en
# 1  http://books.google.com/books/content?id=Nvkwj...  9781451658903       en
# ...
